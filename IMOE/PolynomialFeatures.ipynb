# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_percentage_error

data_dirs = [
    'dataset/UL-NCA',
    'dataset/UL-NCM',
    'dataset/UL-NCMNCA'
]
output_dir = 'results'
os.makedirs(output_dir, exist_ok=True)

degree = 3
window_size = 50
prediction_steps = 50
step_size = 1
all_results = []

def polynomial_fit_and_predict(X, y, degree=3):
    poly = PolynomialFeatures(degree=degree)
    X_poly = poly.fit_transform(X)
    model = LinearRegression()
    model.fit(X_poly, y)
    return model, poly

for data_dir in data_dirs:
    print(f"\nProcessing directory: {data_dir}")
    
    for filename in os.listdir(data_dir):
        if filename.endswith('.csv'):
            filepath = os.path.join(data_dir, filename)
            print(f"\nProcessing {filename}...")
            
            try:
                data = pd.read_csv(filepath)
                discharge_capacity = data['Discharge_Capacity'].values / 1000
                total_cycles = len(discharge_capacity)
                
                all_predictions = []
                actual_values = []
                
                for start_idx in range(0, total_cycles - window_size - prediction_steps + 1, step_size):
                    window_data = discharge_capacity[start_idx:start_idx+window_size]
                    future_data = discharge_capacity[start_idx+window_size:start_idx+window_size+prediction_steps]
                    
                    X = np.arange(start_idx, start_idx+window_size).reshape(-1, 1)
                    y = window_data
                    
                    model, poly = polynomial_fit_and_predict(X, y, degree=degree)
                    future_X = np.arange(start_idx+window_size, start_idx+window_size+prediction_steps).reshape(-1, 1)
                    future_X_poly = poly.transform(future_X)
                    predicted = model.predict(future_X_poly)
                    
                    all_predictions.append(predicted)
                    actual_values.append(future_data)
                
                all_predictions = np.array(all_predictions)
                actual_values = np.array(actual_values)
                
                mape = mean_absolute_percentage_error(actual_values.flatten(), all_predictions.flatten()) * 100
                rmse = np.sqrt(np.mean((actual_values - all_predictions)**2))
                
                print(f"File: {filename} | MAPE: {mape:.2f}% | RMSE: {rmse:.6f}")
                
                all_results.append({
                    'dataset': os.path.basename(os.path.dirname(data_dir)),
                    'filename': filename,
                    'mape': mape,
                    'rmse': rmse,
                    'predictions': all_predictions,
                    'actual': actual_values
                })
                
                plt.figure(figsize=(12, 6))
                
                plt.plot(np.arange(total_cycles), discharge_capacity, 'k-', linewidth=2, label='True Capacity')

                for i in range(all_predictions.shape[0]):
                    start_cycle = i * step_size + window_size
                    pred_cycles = np.arange(start_cycle, start_cycle + prediction_steps)
                    plt.plot(pred_cycles, all_predictions[i], 'r-', alpha=0.1, linewidth=0.5)
                
                mean_pred = np.mean(all_predictions, axis=0)
                mean_start = (all_predictions.shape[0]-1)*step_size + window_size
                mean_cycles = np.arange(mean_start, mean_start + prediction_steps)
                plt.plot(mean_cycles, mean_pred, 'b--', linewidth=2, 
                         label=f'Mean Prediction (MAPE: {mape:.2f}%)')
                
                plt.axvspan(total_cycles - window_size - prediction_steps, 
                            total_cycles - prediction_steps, 
                            color='yellow', alpha=0.1, label='Last Input Window')
                plt.title(f'Polynomial Fit (deg={degree}) - {os.path.basename(data_dir)} - {filename}')
                plt.xlabel('Cycle Number')
                plt.ylabel('Discharge Capacity (Normalized)')
                plt.legend()
                plt.grid(True, alpha=0.3)
                
                dataset_name = os.path.basename(data_dir)
                os.makedirs(os.path.join(output_dir, dataset_name), exist_ok=True)
                output_path = os.path.join(output_dir, dataset_name, f'polyfit_{filename.replace(".csv", ".png")}')
                plt.savefig(output_path, dpi=300, bbox_inches='tight')
                plt.close()
                
            except Exception as e:
                print(f"Error processing {filename}: {str(e)}")
                continue

if all_results:
    datasets = set(result['dataset'] for result in all_results)
    for dataset in datasets:
        dataset_results = [result for result in all_results if result['dataset'] == dataset]
        avg_mape = np.mean([result['mape'] for result in dataset_results])
        avg_rmse = np.mean([result['rmse'] for result in dataset_results])
        print(f"\nDataset {dataset} (n={len(dataset_results)}):")
        print(f"Average MAPE: {avg_mape:.2f}%")
        print(f"Average RMSE: {avg_rmse:.6f}")

    total_mape = np.mean([result['mape'] for result in all_results])
    total_rmse = np.mean([result['rmse'] for result in all_results])
    
    print("\n" + "="*50)
    print(f"Overall Results (averaged over {len(all_results)} files from {len(data_dirs)} datasets):")
    print(f"Average MAPE: {total_mape:.2f}%")
    print(f"Average RMSE: {total_rmse:.6f}")
    summary_df = pd.DataFrame(all_results)
    summary_df.to_csv(os.path.join(output_dir, 'summary_results.csv'), index=False)

    stats_df = summary_df.groupby('dataset').agg({'mape': ['mean', 'std'], 'rmse': ['mean', 'std']})
    stats_df.to_csv(os.path.join(output_dir, 'dataset_stats.csv'))
else:
    print("No valid files processed.")

print("\nProcessing completed.")
# Out:
# Processing directory: dataset/UL-NCA
#
# Processing CY25-025_1-#1.csv...
# File: CY25-025_1-#1.csv | MAPE: 4.33% | RMSE: 0.354796
#
# Processing CY25-025_1-#2.csv...
# File: CY25-025_1-#2.csv | MAPE: 0.18% | RMSE: 0.009881
#
# Processing CY25-025_1-#3.csv...
# File: CY25-025_1-#3.csv | MAPE: 0.50% | RMSE: 0.022681
#
# Processing CY25-025_1-#4.csv...
# File: CY25-025_1-#4.csv | MAPE: 0.47% | RMSE: 0.020662
#
# Processing CY25-025_1-#5.csv...
# File: CY25-025_1-#5.csv | MAPE: 0.47% | RMSE: 0.020112
#
# Processing CY25-025_1-#6.csv...
# File: CY25-025_1-#6.csv | MAPE: 0.67% | RMSE: 0.034586
#
# Processing CY25-025_1-#7.csv...
# File: CY25-025_1-#7.csv | MAPE: 0.73% | RMSE: 0.035656
#
# Processing CY25-05_1-#1.csv...
# File: CY25-05_1-#1.csv | MAPE: 2.04% | RMSE: 0.088761
#
# Processing CY25-05_1-#10.csv...
# File: CY25-05_1-#10.csv | MAPE: 0.58% | RMSE: 0.041239
#
# Processing CY25-05_1-#11.csv...
# File: CY25-05_1-#11.csv | MAPE: 1.19% | RMSE: 0.058229
#
# Processing CY25-05_1-#12.csv...
# File: CY25-05_1-#12.csv | MAPE: 1.31% | RMSE: 0.068122
#
# Processing CY25-05_1-#13.csv...
# File: CY25-05_1-#13.csv | MAPE: 2.31% | RMSE: 0.141326
#
# Processing CY25-05_1-#14.csv...
# File: CY25-05_1-#14.csv | MAPE: 0.50% | RMSE: 0.028637
#
# Processing CY25-05_1-#15.csv...
# File: CY25-05_1-#15.csv | MAPE: 1.12% | RMSE: 0.068926
#
# Processing CY25-05_1-#16.csv...
# File: CY25-05_1-#16.csv | MAPE: 1.43% | RMSE: 0.063408
#
# Processing CY25-05_1-#17.csv...
# File: CY25-05_1-#17.csv | MAPE: 1.46% | RMSE: 0.100344
#
# Processing CY25-05_1-#18.csv...
# File: CY25-05_1-#18.csv | MAPE: 1.49% | RMSE: 0.075719
#
# Processing CY25-05_1-#19.csv...
# File: CY25-05_1-#19.csv | MAPE: 1.10% | RMSE: 0.055278
#
# Processing CY25-05_1-#2.csv...
# File: CY25-05_1-#2.csv | MAPE: 0.90% | RMSE: 0.043872
#
# Processing CY25-05_1-#3.csv...
# File: CY25-05_1-#3.csv | MAPE: 0.97% | RMSE: 0.061463
#
# Processing CY25-05_1-#4.csv...
# File: CY25-05_1-#4.csv | MAPE: 1.02% | RMSE: 0.085204
#
# Processing CY25-05_1-#5.csv...
# File: CY25-05_1-#5.csv | MAPE: 1.46% | RMSE: 0.079034
#
# Processing CY25-05_1-#6.csv...
# File: CY25-05_1-#6.csv | MAPE: 0.51% | RMSE: 0.025568
#
# Processing CY25-05_1-#7.csv...
# File: CY25-05_1-#7.csv | MAPE: 0.57% | RMSE: 0.041358
#
# Processing CY25-05_1-#8.csv...
# File: CY25-05_1-#8.csv | MAPE: 5.31% | RMSE: 0.218434
#
# Processing CY25-05_1-#9.csv...
# File: CY25-05_1-#9.csv | MAPE: 2.13% | RMSE: 0.093304
#
# Processing CY25-1_1-#1.csv...
# Error processing CY25-1_1-#1.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#2.csv...
# Error processing CY25-1_1-#2.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#3.csv...
# Error processing CY25-1_1-#3.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#4.csv...
# Error processing CY25-1_1-#4.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#5.csv...
# Error processing CY25-1_1-#5.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#6.csv...
# Error processing CY25-1_1-#6.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#7.csv...
# Error processing CY25-1_1-#7.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#8.csv...
# Error processing CY25-1_1-#8.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-1_1-#9.csv...
# Error processing CY25-1_1-#9.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY35-05_1-#1.csv...
# File: CY35-05_1-#1.csv | MAPE: 0.22% | RMSE: 0.011229
#
# Processing CY35-05_1-#2.csv...
# File: CY35-05_1-#2.csv | MAPE: 0.47% | RMSE: 0.036194
#
# Processing CY35-05_1-#3.csv...
# Error processing CY35-05_1-#3.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY45-05_1-#1.csv...
# File: CY45-05_1-#1.csv | MAPE: 0.30% | RMSE: 0.015111
#
# Processing CY45-05_1-#10.csv...
# File: CY45-05_1-#10.csv | MAPE: 0.49% | RMSE: 0.041325
#
# Processing CY45-05_1-#11.csv...
# File: CY45-05_1-#11.csv | MAPE: 0.48% | RMSE: 0.037038
#
# Processing CY45-05_1-#12.csv...
# File: CY45-05_1-#12.csv | MAPE: 0.22% | RMSE: 0.012417
#
# Processing CY45-05_1-#13.csv...
# File: CY45-05_1-#13.csv | MAPE: 0.31% | RMSE: 0.018155
#
# Processing CY45-05_1-#14.csv...
# File: CY45-05_1-#14.csv | MAPE: 0.19% | RMSE: 0.011837
#
# Processing CY45-05_1-#15.csv...
# File: CY45-05_1-#15.csv | MAPE: 0.58% | RMSE: 0.034638
#
# Processing CY45-05_1-#16.csv...
# File: CY45-05_1-#16.csv | MAPE: 0.57% | RMSE: 0.043307
#
# Processing CY45-05_1-#17.csv...
# File: CY45-05_1-#17.csv | MAPE: 0.77% | RMSE: 0.050182
#
# Processing CY45-05_1-#18.csv...
# File: CY45-05_1-#18.csv | MAPE: 0.39% | RMSE: 0.036179
#
# Processing CY45-05_1-#19.csv...
# File: CY45-05_1-#19.csv | MAPE: 0.52% | RMSE: 0.045668
#
# Processing CY45-05_1-#2.csv...
# File: CY45-05_1-#2.csv | MAPE: 0.61% | RMSE: 0.031776
#
# Processing CY45-05_1-#20.csv...
# File: CY45-05_1-#20.csv | MAPE: 0.32% | RMSE: 0.019604
#
# Processing CY45-05_1-#21.csv...
# File: CY45-05_1-#21.csv | MAPE: 0.49% | RMSE: 0.040874
#
# Processing CY45-05_1-#22.csv...
# File: CY45-05_1-#22.csv | MAPE: 0.42% | RMSE: 0.041722
#
# Processing CY45-05_1-#23.csv...
# File: CY45-05_1-#23.csv | MAPE: 0.16% | RMSE: 0.010203
#
# Processing CY45-05_1-#24.csv...
# File: CY45-05_1-#24.csv | MAPE: 0.50% | RMSE: 0.036026
#
# Processing CY45-05_1-#25.csv...
# File: CY45-05_1-#25.csv | MAPE: 0.35% | RMSE: 0.024648
#
# Processing CY45-05_1-#26.csv...
# File: CY45-05_1-#26.csv | MAPE: 0.34% | RMSE: 0.024986
#
# Processing CY45-05_1-#27.csv...
# File: CY45-05_1-#27.csv | MAPE: 0.69% | RMSE: 0.042176
#
# Processing CY45-05_1-#28.csv...
# File: CY45-05_1-#28.csv | MAPE: 0.28% | RMSE: 0.016650
#
# Processing CY45-05_1-#3.csv...
# File: CY45-05_1-#3.csv | MAPE: 0.38% | RMSE: 0.018284
#
# Processing CY45-05_1-#4.csv...
# File: CY45-05_1-#4.csv | MAPE: 0.77% | RMSE: 0.039645
#
# Processing CY45-05_1-#5.csv...
# File: CY45-05_1-#5.csv | MAPE: 1.52% | RMSE: 0.104119
#
# Processing CY45-05_1-#6.csv...
# File: CY45-05_1-#6.csv | MAPE: 1.51% | RMSE: 0.090671
#
# Processing CY45-05_1-#7.csv...
# File: CY45-05_1-#7.csv | MAPE: 0.32% | RMSE: 0.016472
#
# Processing CY45-05_1-#8.csv...
# File: CY45-05_1-#8.csv | MAPE: 1.02% | RMSE: 0.059891
#
# Processing CY45-05_1-#9.csv...
# File: CY45-05_1-#9.csv | MAPE: 0.49% | RMSE: 0.027766
#
# Processing directory: dataset/UL-NCM
#
# Processing CY25-05_1-#1.csv...
# File: CY25-05_1-#1.csv | MAPE: 0.18% | RMSE: 0.011310
#
# Processing CY25-05_1-#10.csv...
# File: CY25-05_1-#10.csv | MAPE: 0.35% | RMSE: 0.015513
#
# Processing CY25-05_1-#11.csv...
# File: CY25-05_1-#11.csv | MAPE: 0.56% | RMSE: 0.024848
#
# Processing CY25-05_1-#12.csv...
# File: CY25-05_1-#12.csv | MAPE: 0.71% | RMSE: 0.031232
#
# Processing CY25-05_1-#13.csv...
# File: CY25-05_1-#13.csv | MAPE: 0.35% | RMSE: 0.015847
#
# Processing CY25-05_1-#14.csv...
# Error processing CY25-05_1-#14.csv: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.
#
# Processing CY25-05_1-#15.csv...
# File: CY25-05_1-#15.csv | MAPE: 1.12% | RMSE: 0.053642
#
# Processing CY25-05_1-#16.csv...
# File: CY25-05_1-#16.csv | MAPE: 1.66% | RMSE: 0.088294
#
# Processing CY25-05_1-#17.csv...
# File: CY25-05_1-#17.csv | MAPE: 0.30% | RMSE: 0.017232
#
# Processing CY25-05_1-#18.csv...
# File: CY25-05_1-#18.csv | MAPE: 0.17% | RMSE: 0.009392
#
# Processing CY25-05_1-#19.csv...
# File: CY25-05_1-#19.csv | MAPE: 0.14% | RMSE: 0.007901
#
# Processing CY25-05_1-#2.csv...
# File: CY25-05_1-#2.csv | MAPE: 0.40% | RMSE: 0.017343
#
# Processing CY25-05_1-#20.csv...
# File: CY25-05_1-#20.csv | MAPE: 0.18% | RMSE: 0.009448
#
# Processing CY25-05_1-#21.csv...
# File: CY25-05_1-#21.csv | MAPE: 0.24% | RMSE: 0.013535
#
# Processing CY25-05_1-#22.csv...
# File: CY25-05_1-#22.csv | MAPE: 0.13% | RMSE: 0.010009
#
# Processing CY25-05_1-#23.csv...
# File: CY25-05_1-#23.csv | MAPE: 0.12% | RMSE: 0.008604
#
# Processing CY25-05_1-#3.csv...
# File: CY25-05_1-#3.csv | MAPE: 0.34% | RMSE: 0.017971
#
# Processing CY25-05_1-#4.csv...
# File: CY25-05_1-#4.csv | MAPE: 0.31% | RMSE: 0.017281
#
# Processing CY25-05_1-#5.csv...
# File: CY25-05_1-#5.csv | MAPE: 0.70% | RMSE: 0.060787
#
# Processing CY25-05_1-#6.csv...
# File: CY25-05_1-#6.csv | MAPE: 0.15% | RMSE: 0.009433
#
# Processing CY25-05_1-#7.csv...
# File: CY25-05_1-#7.csv | MAPE: 0.21% | RMSE: 0.010041
#
# Processing CY25-05_1-#8.csv...
# File: CY25-05_1-#8.csv | MAPE: 0.61% | RMSE: 0.027087
#
# Processing CY25-05_1-#9.csv...
# File: CY25-05_1-#9.csv | MAPE: 0.39% | RMSE: 0.017568
#
# Processing CY35-05_1-#1.csv...
# File: CY35-05_1-#1.csv | MAPE: 0.24% | RMSE: 0.012225
#
# Processing CY35-05_1-#2.csv...
# File: CY35-05_1-#2.csv | MAPE: 0.25% | RMSE: 0.012735
#
# Processing CY35-05_1-#3.csv...
# File: CY35-05_1-#3.csv | MAPE: 0.23% | RMSE: 0.011576
#
# Processing CY35-05_1-#4.csv...
# File: CY35-05_1-#4.csv | MAPE: 0.21% | RMSE: 0.010932
#
# Processing CY45-05_1-#1.csv...
# File: CY45-05_1-#1.csv | MAPE: 0.38% | RMSE: 0.017583
#
# Processing CY45-05_1-#10.csv...
# File: CY45-05_1-#10.csv | MAPE: 0.55% | RMSE: 0.024212
#
# Processing CY45-05_1-#11.csv...
# File: CY45-05_1-#11.csv | MAPE: 0.30% | RMSE: 0.013093
#
# Processing CY45-05_1-#12.csv...
# File: CY45-05_1-#12.csv | MAPE: 0.44% | RMSE: 0.020557
#
# Processing CY45-05_1-#13.csv...
# File: CY45-05_1-#13.csv | MAPE: 0.31% | RMSE: 0.015753
#
# Processing CY45-05_1-#14.csv...
# File: CY45-05_1-#14.csv | MAPE: 0.10% | RMSE: 0.005465
#
# Processing CY45-05_1-#15.csv...
# File: CY45-05_1-#15.csv | MAPE: 0.29% | RMSE: 0.015128
#
# Processing CY45-05_1-#16.csv...
# File: CY45-05_1-#16.csv | MAPE: 0.27% | RMSE: 0.012562
#
# Processing CY45-05_1-#17.csv...
# File: CY45-05_1-#17.csv | MAPE: 0.17% | RMSE: 0.010167
#
# Processing CY45-05_1-#18.csv...
# File: CY45-05_1-#18.csv | MAPE: 0.13% | RMSE: 0.008568
#
# Processing CY45-05_1-#19.csv...
# File: CY45-05_1-#19.csv | MAPE: 0.16% | RMSE: 0.010002
#
# Processing CY45-05_1-#2.csv...
# File: CY45-05_1-#2.csv | MAPE: 0.40% | RMSE: 0.019012
#
# Processing CY45-05_1-#20.csv...
# File: CY45-05_1-#20.csv | MAPE: 0.19% | RMSE: 0.010425
#
# Processing CY45-05_1-#21.csv...
# File: CY45-05_1-#21.csv | MAPE: 0.23% | RMSE: 0.015023
#
# Processing CY45-05_1-#22.csv...
# File: CY45-05_1-#22.csv | MAPE: 0.15% | RMSE: 0.008107
#
# Processing CY45-05_1-#23.csv...
# File: CY45-05_1-#23.csv | MAPE: 0.12% | RMSE: 0.006267
#
# Processing CY45-05_1-#24.csv...
# File: CY45-05_1-#24.csv | MAPE: 0.18% | RMSE: 0.009062
#
# Processing CY45-05_1-#25.csv...
# File: CY45-05_1-#25.csv | MAPE: 0.24% | RMSE: 0.011528
#
# Processing CY45-05_1-#26.csv...
# File: CY45-05_1-#26.csv | MAPE: 0.17% | RMSE: 0.008217
#
# Processing CY45-05_1-#27.csv...
# File: CY45-05_1-#27.csv | MAPE: 0.17% | RMSE: 0.008252
#
# Processing CY45-05_1-#28.csv...
# File: CY45-05_1-#28.csv | MAPE: 0.18% | RMSE: 0.012282
#
# Processing CY45-05_1-#3.csv...
# File: CY45-05_1-#3.csv | MAPE: 0.47% | RMSE: 0.021912
#
# Processing CY45-05_1-#4.csv...
# File: CY45-05_1-#4.csv | MAPE: 0.54% | RMSE: 0.026226
#
# Processing CY45-05_1-#5.csv...
# File: CY45-05_1-#5.csv | MAPE: 0.54% | RMSE: 0.025144
#
# Processing CY45-05_1-#6.csv...
# File: CY45-05_1-#6.csv | MAPE: 0.56% | RMSE: 0.025894
#
# Processing CY45-05_1-#7.csv...
# File: CY45-05_1-#7.csv | MAPE: 0.63% | RMSE: 0.027949
#
# Processing CY45-05_1-#8.csv...
# File: CY45-05_1-#8.csv | MAPE: 0.61% | RMSE: 0.028527
#
# Processing CY45-05_1-#9.csv...
# File: CY45-05_1-#9.csv | MAPE: 0.55% | RMSE: 0.025170
#
# Processing directory: dataset/UL-NCMNCA
#
# Processing CY25-05_1-#1.csv...
# File: CY25-05_1-#1.csv | MAPE: 1.98% | RMSE: 0.065227
#
# Processing CY25-05_1-#2.csv...
# File: CY25-05_1-#2.csv | MAPE: 2.37% | RMSE: 0.078995
#
# Processing CY25-05_1-#3.csv...
# File: CY25-05_1-#3.csv | MAPE: 2.23% | RMSE: 0.072669
#
# Processing CY25-05_2-#1.csv...
# File: CY25-05_2-#1.csv | MAPE: 2.81% | RMSE: 0.095797
#
# Processing CY25-05_2-#2.csv...
# File: CY25-05_2-#2.csv | MAPE: 2.48% | RMSE: 0.083642
#
# Processing CY25-05_2-#3.csv...
# File: CY25-05_2-#3.csv | MAPE: 3.13% | RMSE: 0.099712
#
# Processing CY25-05_4-#1.csv...
# File: CY25-05_4-#1.csv | MAPE: 2.42% | RMSE: 0.081647
#
# Processing CY25-05_4-#2.csv...
# File: CY25-05_4-#2.csv | MAPE: 2.51% | RMSE: 0.085495
#
# Processing CY25-05_4-#3.csv...
# File: CY25-05_4-#3.csv | MAPE: 3.00% | RMSE: 0.107044
#
# Dataset dataset (n=119):
# Average MAPE: 0.78%
# Average RMSE: 0.039744
#
# ==================================================
# Overall Results (averaged over 119 files from 3 datasets):
# Average MAPE: 0.78%
# Average RMSE: 0.039744
#
# Processing completed.
